# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

from preprocessing import parse_fn , parse_fn

# %%
val_spl , train_spl = tfds.Split.TRAIN.subsplit([10,90])
train_data , info =tfds.load('cifar10',split = train_spl , with_info=True)

val_data = tfds.load('cifar10',split=train_spl)

test_data = tfds.load('cifar10',split=tfds.Split.TEST)

# %%
AUTOTUNE =tf.data.experimental.AUTOTUNE
batch_size = 64
train_num = int(info.splits['train'].num_examples/10)*9


train_data = train_data.shuffle(train_num)
train_data = train_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
train_data = train_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)


val_data = val_data.shuffle(train_num)
val_data = val_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
val_data = val_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)


test_data = test_data.shuffle(train_num)
test_data = test_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
test_data = test_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %%
"""
def build_train(run_name , init):
    inputs = keras.Input(shape=(32,32,3))
    x = layers.Conv2D(64,(3,3),activation='relu',kernel_initializer=init)(inputs)
    x = layers.MaxPool2D()(x)
    x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=init)(x)
    x = layers.Conv2D(256,(3,3),activation='relu',kernel_initializer=init)(x)
    x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=init)(x)
    x = layers.Conv2D(64 ,(3,3),activation='relu',kernel_initializer=init)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64 ,activation='relu',kernel_initializer=init)(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(10,activation='softmax')(x)
    
    model = keras.Model(inputs, outputs)
    
    
    logfiles ='lab5-logs/{}-{}'.format(run_name, init.__class__.__name__)
    
    model_cbk = keras.callbacks.TensorBoard(log_dir=logfiles , histogram_freq=1)

    modelfiles = model_dir+'/{}best-model.h5'.format(run_name)
    
    model_mckp = keras.callbacks.ModelCheckpoint(modelfiles,
                                                 monitor='val_categorical_accuracy',
                                                 save_best_only=True,
                                                 mode='max')
    
    model.compile(keras.optimizers.Adam(),
                  loss=keras.losses.CategoricalCrossentropy(),
                  metrics=[keras.metrics.CategoricalAccuracy()])
    
    model.fit(train_data,
              epochs=100,
              validation_data=val_data,
              callbacks=[model_cbk,model_mckp])
"""

# %%
""""
sesion_num =1
model_dir = 'lab5-logs/models'
os.makedirs(model_dir)


weight =[initializers.RandomNormal(0,0.01),
         initializers.glorot_normal(),
         initializers.he_normal()]
"""
# Out:
# WARNING:tensorflow:From C:\Users\gg246\Anaconda3\envs\aa\lib\site-packages\tensorflow_core\python\keras\initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\gg246\Anaconda3\envs\aa\lib\site-packages\tensorflow_core\python\keras\initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
inputs = keras.Input(shape=(32,32,3))
x = layers.Conv2D(64,(3,3),activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(inputs)
x = layers.MaxPool2D()(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(x)
x = layers.Conv2D(256,(3,3),activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(x)
x = layers.Conv2D(64 ,(3,3),activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(x)
x = layers.Flatten()(x)
x = layers.Dense(64 ,activation='relu',kernel_initializer=initializers.RandomNormal(0,0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10,activation='softmax')(x)
    
model_1 = keras.Model(inputs, outputs)
    
model_dir = 'lab5-logs/models'
#os.makedirs(model_dir)
#儲存回調函數
log_dir = os.path.join('lab5-logs','model-1')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
#最佳
model_mckp = keras.callbacks.ModelCheckpoint(model_dir+'Bestmodel-1.h5',
                                             monitor='val_categorical_accuracy',
                                             save_best_only=True,
                                             mode='max')    
    
    
model_1.compile(keras.optimizers.Adam(),
                loss=keras.losses.CategoricalCrossentropy(),
                metrics=[keras.metrics.CategoricalAccuracy()])
    
history =model_1.fit(train_data,
                     epochs=100,
                     validation_steps=50,
                     validation_data=val_data,
                    callbacks=[model_cbk,model_mckp])
# Out:
# Train on None steps, validate on 50 steps
# Epoch 1/100
# 704/704 [==============================] - 18s 26ms/step - loss: 2.0682 - categorical_accuracy: 0.2154 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.8275 - categorical_accuracy: 0.3195 - val_loss: 1.7438 - val_categorical_accuracy: 0.3756
# Epoch 3/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.6878 - categorical_accuracy: 0.3768 - val_loss: 1.5331 - val_categorical_accuracy: 0.4144
# Epoch 4/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.5731 - categorical_accuracy: 0.4238 - val_loss: 1.4130 - val_categorical_accuracy: 0.4875
# Epoch 5/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.4866 - categorical_accuracy: 0.4564 - val_loss: 1.3234 - val_categorical_accuracy: 0.5356
# Epoch 6/100
# ...

# %%
inputs = keras.Input(shape=(32,32,3))
x = layers.Conv2D(64,(3,3),activation='relu',kernel_initializer=initializers.he_normal())(inputs)
x = layers.MaxPool2D()(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.he_normal())(x)
x = layers.Conv2D(256,(3,3),activation='relu',kernel_initializer=initializers.he_normal())(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.he_normal())(x)
x = layers.Conv2D(64 ,(3,3),activation='relu',kernel_initializer=initializers.he_normal())(x)
x = layers.Flatten()(x)
x = layers.Dense(64 ,activation='relu',kernel_initializer=initializers.he_normal())(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10,activation='softmax')(x)
    
model_3 = keras.Model(inputs, outputs)
    
model_dir = 'lab5-logs/models'
#os.makedirs(model_dir)
#儲存回調函數
log_dir = os.path.join('lab5-logs','model-3')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
#最佳
model_mckp = keras.callbacks.ModelCheckpoint(model_dir+'Bestmodel-3.h5',
                                             monitor='val_categorical_accuracy',
                                             save_best_only=True,
                                             mode='max')    
    
    
model_3.compile(keras.optimizers.Adam(),
                loss=keras.losses.CategoricalCrossentropy(),
                metrics=[keras.metrics.CategoricalAccuracy()])
    
history_3 =model_3.fit(train_data,
                     epochs=100,
                     validation_steps=50,
                     validation_data=val_data,
                    callbacks=[model_cbk,model_mckp])
# Out:
# Train on None steps, validate on 50 steps
# Epoch 1/100
# 704/704 [==============================] - 19s 27ms/step - loss: 1.8153 - categorical_accuracy: 0.3269 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.4580 - categorical_accuracy: 0.4754 - val_loss: 1.1837 - val_categorical_accuracy: 0.5791
# Epoch 3/100
# 704/704 [==============================] - 18s 25ms/step - loss: 1.2672 - categorical_accuracy: 0.5504 - val_loss: 1.0920 - val_categorical_accuracy: 0.6134
# Epoch 4/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.1304 - categorical_accuracy: 0.6053 - val_loss: 0.9219 - val_categorical_accuracy: 0.6709
# Epoch 5/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.0255 - categorical_accuracy: 0.6430 - val_loss: 0.8172 - val_categorical_accuracy: 0.7166
# Epoch 6/100
# ...

# %%
inputs = keras.Input(shape=(32,32,3))
x = layers.Conv2D(64,(3,3),activation='relu',kernel_initializer=initializers.glorot_normal())(inputs)
x = layers.MaxPool2D()(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.glorot_normal())(x)
x = layers.Conv2D(256,(3,3),activation='relu',kernel_initializer=initializers.glorot_normal())(x)
x = layers.Conv2D(128,(3,3),activation='relu',kernel_initializer=initializers.glorot_normal())(x)
x = layers.Conv2D(64 ,(3,3),activation='relu',kernel_initializer=initializers.glorot_normal())(x)
x = layers.Flatten()(x)
x = layers.Dense(64 ,activation='relu',kernel_initializer=initializers.glorot_normal())(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10,activation='softmax')(x)
    
model_2 = keras.Model(inputs, outputs)
    
model_dir = 'lab5-logs/models'
#os.makedirs(model_dir)
#儲存回調函數
log_dir = os.path.join('lab5-logs','model-2')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
#最佳
model_mckp = keras.callbacks.ModelCheckpoint(model_dir+'Bestmodel-2.h5',
                                             monitor='val_categorical_accuracy',
                                             save_best_only=True,
                                             mode='max')    
    
    
model_2.compile(keras.optimizers.Adam(),
                loss=keras.losses.CategoricalCrossentropy(),
                metrics=[keras.metrics.CategoricalAccuracy()])
    
history_2 =model_2.fit(train_data,
                     epochs=100,
                     validation_steps=50,
                     validation_data=val_data,
                    callbacks=[model_cbk,model_mckp])
# Out:
# Train on None steps, validate on 50 steps
# Epoch 1/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.9335 - categorical_accuracy: 0.2750 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 17s 23ms/step - loss: 1.5397 - categorical_accuracy: 0.4413 - val_loss: 1.2925 - val_categorical_accuracy: 0.5231
# Epoch 3/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.3664 - categorical_accuracy: 0.5141 - val_loss: 1.1716 - val_categorical_accuracy: 0.5775
# Epoch 4/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.2340 - categorical_accuracy: 0.5650 - val_loss: 1.0343 - val_categorical_accuracy: 0.6147
# Epoch 5/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.1406 - categorical_accuracy: 0.5971 - val_loss: 0.9065 - val_categorical_accuracy: 0.6759
# Epoch 6/100
# ...

# %%
# %load_ext tensorboard

# %%
# %reload_ext tensorboard

# %%
tensorboard --logdir lab5-logs
# Out:
# Reusing TensorBoard on port 6006 (pid 14936), started 0:01:30 ago. (Use '!kill 14936' to kill it.)
#       <iframe id="tensorboard-frame-466d13df86857d5e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-466d13df86857d5e");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
